# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
stock_info = pd.read_excel('/Users/lofang/Desktop/python/csv files/1215.tw.xlsx')
stock_info
# Out:
#            公司         年月 TEJ產業_名稱  應收帳款週轉次數   負債比率 集團控制型態  單月營收(千元)  \
# 0     1215 卜蜂 2019-01-01     油脂飼料      8.89  53.71      F   1885469
# 1     1215 卜蜂 2019-01-02     油脂飼料      8.89  53.71      F   1885469
# 2     1215 卜蜂 2019-01-03     油脂飼料      8.89  53.71      F   1885469
# 3     1215 卜蜂 2019-01-04     油脂飼料      8.89  53.71      F   1885469
# 4     1215 卜蜂 2019-01-05     油脂飼料      8.89  53.71      F   1885469
# ...       ...        ...      ...       ...    ...    ...       ...
# 1364  1215 卜蜂 2022-09-26     油脂飼料      9.97  63.59      F   2418414
# 1365  1215 卜蜂 2022-09-27     油脂飼料      9.97  63.59      F   2418414
# 1366  1215 卜蜂 2022-09-28     油脂飼料      9.97  63.59      F   2418414
# 1367  1215 卜蜂 2022-09-29     油脂飼料      9.97  63.59      F   2418414
# 1368  1215 卜蜂 2022-09-30     油脂飼料      9.97  63.59      F   2418414
#
#       ROA(A)稅後息前  ROE(A)－稅後  公司年資
# 0           1.72       3.55    32
# 1           1.72       3.55    32
# 2           1.72       3.55    32
# 3           1.72       3.55    32
# 4           1.72       3.55    32
# ...          ...        ...   ...
# 1364        5.28      13.49    35
# 1365        5.28      13.49    35
# 1366        5.28      13.49    35
# 1367        5.28      13.49    35
# 1368        5.28      13.49    35
#
# [1369 rows x 10 columns]

# %%
stock_info.rename(columns = {'年月':'Date','TEJ產業_名稱':'Industry','應收帳款週轉次數':'Receivable Turnover Ratio','負債比率':'Debt Ratio','單月營收(千元)':'Revenue(k/per Month)','ROA(A)稅後息前':'ROA(Pre-tax)','ROE(A)－稅後':'ROE(After-tax)','公司年資':'Age'}, inplace = True)
stock_info
# Out:
#            公司       Date Industry  Receivable Turnover Ratio  Debt Ratio  \
# 0     1215 卜蜂 2019-01-01     油脂飼料                       8.89       53.71
# 1     1215 卜蜂 2019-01-02     油脂飼料                       8.89       53.71
# 2     1215 卜蜂 2019-01-03     油脂飼料                       8.89       53.71
# 3     1215 卜蜂 2019-01-04     油脂飼料                       8.89       53.71
# 4     1215 卜蜂 2019-01-05     油脂飼料                       8.89       53.71
# ...       ...        ...      ...                        ...         ...
# 1364  1215 卜蜂 2022-09-26     油脂飼料                       9.97       63.59
# 1365  1215 卜蜂 2022-09-27     油脂飼料                       9.97       63.59
# 1366  1215 卜蜂 2022-09-28     油脂飼料                       9.97       63.59
# 1367  1215 卜蜂 2022-09-29     油脂飼料                       9.97       63.59
# 1368  1215 卜蜂 2022-09-30     油脂飼料                       9.97       63.59
#
#      集團控制型態  Revenue(k/per Month)  ROA(Pre-tax)  ROE(After-tax)  Age
# 0         F               1885469          1.72            3.55   32
# 1         F               1885469          1.72            3.55   32
# 2         F               1885469          1.72            3.55   32
# 3         F               1885469          1.72            3.55   32
# 4         F               1885469          1.72            3.55   32
# ...     ...                   ...           ...             ...  ...
# 1364      F               2418414          5.28           13.49   35
# 1365      F               2418414          5.28           13.49   35
# 1366      F               2418414          5.28           13.49   35
# 1367      F               2418414          5.28           13.49   35
# 1368      F               2418414          5.28           13.49   35
#
# [1369 rows x 10 columns]

# %%
import yfinance as yf
his_price = yf.download('1225.tw',start = '2019-01-01', end = '2022-09-30')
his_price
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2019-01-02  76.099998  76.099998  75.000000  75.000000  66.416626    3002
# 2019-01-03  76.900002  76.900002  76.900002  76.900002  68.099182    1013
# 2019-01-04  76.900002  76.900002  76.900002  76.900002  68.099182       0
# 2019-01-07  76.900002  76.900002  76.900002  76.900002  68.099182       0
# 2019-01-08  74.800003  74.800003  74.199997  74.199997  65.708176   10043
# ...               ...        ...        ...        ...        ...     ...
# 2022-09-23  51.500000  52.299999  51.500000  52.299999  52.299999    2010
# 2022-09-26  52.099998  52.299999  51.500000  52.000000  52.000000   20106
# 2022-09-27  52.000000  52.200001  51.000000  52.200001  52.200001   25487
# 2022-09-28  51.000000  51.000000  51.000000  51.000000  51.000000   15004
# 2022-09-29  51.099998  51.099998  51.000000  51.000000  51.000000   14009
#
# [910 rows x 6 columns]

# %%
combined = pd.merge(stock_info,his_price, how = "right", on = ["Date"])
combined['Daily_Return'] = combined['Adj Close'].pct_change().dropna()
combined = combined.drop(index = 0)
combined
#these columns will serve as independent variables in OLS analysis
# Out:
#           公司       Date Industry  Receivable Turnover Ratio  Debt Ratio  \
# 1    1215 卜蜂 2019-01-03     油脂飼料                       8.89       53.71
# 2    1215 卜蜂 2019-01-04     油脂飼料                       8.89       53.71
# 3    1215 卜蜂 2019-01-07     油脂飼料                       8.89       53.71
# 4    1215 卜蜂 2019-01-08     油脂飼料                       8.89       53.71
# 5    1215 卜蜂 2019-01-09     油脂飼料                       8.89       53.71
# ..       ...        ...      ...                        ...         ...
# 905  1215 卜蜂 2022-09-23     油脂飼料                       9.97       63.59
# 906  1215 卜蜂 2022-09-26     油脂飼料                       9.97       63.59
# 907  1215 卜蜂 2022-09-27     油脂飼料                       9.97       63.59
# 908  1215 卜蜂 2022-09-28     油脂飼料                       9.97       63.59
# 909  1215 卜蜂 2022-09-29     油脂飼料                       9.97       63.59
#
#     集團控制型態  Revenue(k/per Month)  ROA(Pre-tax)  ROE(After-tax)  Age  \
# 1        F               1885469          1.72            3.55   32
# 2        F               1885469          1.72            3.55   32
# 3        F               1885469          1.72            3.55   32
# 4        F               1885469          1.72            3.55   32
# 5        F               1885469          1.72            3.55   32
# ..     ...                   ...           ...             ...  ...
# 905      F               2418414          5.28           13.49   35
# 906      F               2418414          5.28           13.49   35
# 907      F               2418414          5.28           13.49   35
# 908      F               2418414          5.28           13.49   35
# 909      F               2418414          5.28           13.49   35
#
#           Open       High        Low      Close  Adj Close  Volume  \
# 1    76.900002  76.900002  76.900002  76.900002  68.099182    1013
# 2    76.900002  76.900002  76.900002  76.900002  68.099182       0
# 3    76.900002  76.900002  76.900002  76.900002  68.099182       0
# 4    74.800003  74.800003  74.199997  74.199997  65.708176   10043
# 5    74.199997  74.199997  74.199997  74.199997  65.708176       0
# ..         ...        ...        ...        ...        ...     ...
# 905  51.500000  52.299999  51.500000  52.299999  52.299999    2010
# 906  52.099998  52.299999  51.500000  52.000000  52.000000   20106
# 907  52.000000  52.200001  51.000000  52.200001  52.200001   25487
# 908  51.000000  51.000000  51.000000  51.000000  51.000000   15004
# 909  51.099998  51.099998  51.000000  51.000000  51.000000   14009
#
#      Daily_Return
# 1        0.025333
# 2        0.000000
# 3        0.000000
# 4       -0.035111
# 5        0.000000
# ..            ...
# 905      0.015534
# 906     -0.005736
# 907      0.003846
# 908     -0.022989
# 909      0.000000
#
# [909 rows x 17 columns]

# %%
df1 = pd.read_csv('/Users/lofang/Desktop/python/csv files/ff_table.csv')
df1['Date'] = pd.to_datetime(df1['Date'])
ff_table = df1[(df1.Date.isin(combined.Date))]
ff_table = ff_table.dropna().reset_index(drop=True)
ff_table
#construct fama french table
# Out:
#           Date    market     rf       SMB       HML
# 0   2019-01-03 -0.006460  0.842  0.111343 -0.183098
# 1   2019-01-04 -0.011579  0.850  0.283376 -0.465596
# 2   2019-01-07  0.022147  0.870 -0.084096  0.457468
# 3   2019-01-08 -0.002784  0.880  0.068160 -0.082656
# 4   2019-01-09  0.018268  0.880 -0.098494  0.406240
# ..         ...       ...    ...       ...       ...
# 897 2022-09-23 -0.011638  1.402  0.067400 -0.452997
# 898 2022-09-26 -0.024096  1.475 -0.234168 -0.305070
# 899 2022-09-27  0.003513  1.665  0.150132  0.116685
# 900 2022-09-28 -0.026074  1.675 -0.156746 -0.481711
# 901 2022-09-29  0.005064  1.655  0.199620 -0.075485
#
# [902 rows x 5 columns]

# %%
ff_table['rf'] = ff_table['rf'] * 0.01
ff_table
# Out:
#           Date    market       rf       SMB       HML
# 0   2019-01-03 -0.006460  0.00842  0.111343 -0.183098
# 1   2019-01-04 -0.011579  0.00850  0.283376 -0.465596
# 2   2019-01-07  0.022147  0.00870 -0.084096  0.457468
# 3   2019-01-08 -0.002784  0.00880  0.068160 -0.082656
# 4   2019-01-09  0.018268  0.00880 -0.098494  0.406240
# ..         ...       ...      ...       ...       ...
# 897 2022-09-23 -0.011638  0.01402  0.067400 -0.452997
# 898 2022-09-26 -0.024096  0.01475 -0.234168 -0.305070
# 899 2022-09-27  0.003513  0.01665  0.150132  0.116685
# 900 2022-09-28 -0.026074  0.01675 -0.156746 -0.481711
# 901 2022-09-29  0.005064  0.01655  0.199620 -0.075485
#
# [902 rows x 5 columns]

# %%
ff_table['mkt-rf'] = ff_table['market'] - ff_table['rf']
ff_table
# Out:
#           Date    market       rf       SMB       HML    mkt-rf
# 0   2019-01-03 -0.006460  0.00842  0.111343 -0.183098 -0.014880
# 1   2019-01-04 -0.011579  0.00850  0.283376 -0.465596 -0.020079
# 2   2019-01-07  0.022147  0.00870 -0.084096  0.457468  0.013447
# 3   2019-01-08 -0.002784  0.00880  0.068160 -0.082656 -0.011584
# 4   2019-01-09  0.018268  0.00880 -0.098494  0.406240  0.009468
# ..         ...       ...      ...       ...       ...       ...
# 897 2022-09-23 -0.011638  0.01402  0.067400 -0.452997 -0.025658
# 898 2022-09-26 -0.024096  0.01475 -0.234168 -0.305070 -0.038846
# 899 2022-09-27  0.003513  0.01665  0.150132  0.116685 -0.013137
# 900 2022-09-28 -0.026074  0.01675 -0.156746 -0.481711 -0.042824
# 901 2022-09-29  0.005064  0.01655  0.199620 -0.075485 -0.011486
#
# [902 rows x 6 columns]

# %%
joint = combined[(combined.Date.isin(ff_table.Date))]
joint = joint.reset_index(drop = True)
joint
#match values between datasets(drop na, drop holidays)
# Out:
#           公司       Date Industry  Receivable Turnover Ratio  Debt Ratio  \
# 0    1215 卜蜂 2019-01-03     油脂飼料                       8.89       53.71
# 1    1215 卜蜂 2019-01-04     油脂飼料                       8.89       53.71
# 2    1215 卜蜂 2019-01-07     油脂飼料                       8.89       53.71
# 3    1215 卜蜂 2019-01-08     油脂飼料                       8.89       53.71
# 4    1215 卜蜂 2019-01-09     油脂飼料                       8.89       53.71
# ..       ...        ...      ...                        ...         ...
# 897  1215 卜蜂 2022-09-23     油脂飼料                       9.97       63.59
# 898  1215 卜蜂 2022-09-26     油脂飼料                       9.97       63.59
# 899  1215 卜蜂 2022-09-27     油脂飼料                       9.97       63.59
# 900  1215 卜蜂 2022-09-28     油脂飼料                       9.97       63.59
# 901  1215 卜蜂 2022-09-29     油脂飼料                       9.97       63.59
#
#     集團控制型態  Revenue(k/per Month)  ROA(Pre-tax)  ROE(After-tax)  Age  \
# 0        F               1885469          1.72            3.55   32
# 1        F               1885469          1.72            3.55   32
# 2        F               1885469          1.72            3.55   32
# 3        F               1885469          1.72            3.55   32
# 4        F               1885469          1.72            3.55   32
# ..     ...                   ...           ...             ...  ...
# 897      F               2418414          5.28           13.49   35
# 898      F               2418414          5.28           13.49   35
# 899      F               2418414          5.28           13.49   35
# 900      F               2418414          5.28           13.49   35
# 901      F               2418414          5.28           13.49   35
#
#           Open       High        Low      Close  Adj Close  Volume  \
# 0    76.900002  76.900002  76.900002  76.900002  68.099182    1013
# 1    76.900002  76.900002  76.900002  76.900002  68.099182       0
# 2    76.900002  76.900002  76.900002  76.900002  68.099182       0
# 3    74.800003  74.800003  74.199997  74.199997  65.708176   10043
# 4    74.199997  74.199997  74.199997  74.199997  65.708176       0
# ..         ...        ...        ...        ...        ...     ...
# 897  51.500000  52.299999  51.500000  52.299999  52.299999    2010
# 898  52.099998  52.299999  51.500000  52.000000  52.000000   20106
# 899  52.000000  52.200001  51.000000  52.200001  52.200001   25487
# 900  51.000000  51.000000  51.000000  51.000000  51.000000   15004
# 901  51.099998  51.099998  51.000000  51.000000  51.000000   14009
#
#      Daily_Return
# 0        0.025333
# 1        0.000000
# 2        0.000000
# 3       -0.035111
# 4        0.000000
# ..            ...
# 897      0.015534
# 898     -0.005736
# 899      0.003846
# 900     -0.022989
# 901      0.000000
#
# [902 rows x 17 columns]

# %%
X = ff_table[['mkt-rf', 'SMB', 'HML']]
y = joint['Daily_Return'] - ff_table['rf']
X = sm.add_constant(X)
ff_model = sm.OLS(y, X).fit()
print(ff_model.summary())
intercept, b1, b2, b3 = ff_model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.141
# Model:                            OLS   Adj. R-squared:                  0.138
# Method:                 Least Squares   F-statistic:                     49.06
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):           2.28e-29
# Time:                        22:28:31   Log-Likelihood:                 2323.7
# No. Observations:                 902   AIC:                            -4639.
# Df Residuals:                     898   BIC:                            -4620.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.350      0.726      -0.002       0.002
# mkt-rf         0.9659      0.113      8.520      0.000       0.743       1.188
# SMB            0.0101      0.006      1.581      0.114      -0.002       0.023
# HML           -0.0228      0.006     -4.090      0.000      -0.034      -0.012
# ==============================================================================
# Omnibus:                      334.627   Durbin-Watson:                   1.895
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4295.408
# Skew:                           1.317   Prob(JB):                         0.00
# Kurtosis:                      13.361   Cond. No.                         185.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#collect coefficients from fama french result
def factor(t):
    X = ff_table[['mkt-rf', 'SMB', 'HML']].head(t+120)
    y = joint['Daily_Return'].head(t+120) - ff_table['rf'].head(t+120)
    X = sm.add_constant(X)
    ff_model = sm.OLS(y, X).fit()
    intercept, b1, b2, b3 = ff_model.params
    c = [intercept, b1, b2, b3]
    return c

# %%
#collect coefficients from fama french result
coefficient = []
for i in range(0,783,1):
    coefficient.append(factor(i))
c_table = pd.DataFrame(coefficient, columns = ['const ','mkt-rf','SMB','HML'])
c_table.index = c_table.index + 1
c_table
# Out:
#        const     mkt-rf       SMB       HML
# 1    0.000100  1.182277  0.036856 -0.013940
# 2   -0.000085  1.166860  0.037363 -0.013699
# 3   -0.000273  1.160779  0.038253 -0.013594
# 4   -0.000453  1.162043  0.039379 -0.013079
# 5   -0.000433  1.171903  0.039313 -0.013607
# ..        ...       ...       ...       ...
# 779 -0.000338  0.966612  0.010385 -0.022749
# 780 -0.000357  0.961092  0.010223 -0.022674
# 781 -0.000361  0.960283  0.010269 -0.022632
# 782 -0.000352  0.963151  0.010359 -0.022648
# 783 -0.000343  0.965910  0.010149 -0.022794
#
# [783 rows x 4 columns]

# %%
def rf(t):
    return ff_table['rf'].loc[t]
def market_premium(t):
    return ff_table['mkt-rf'].loc[t]
def size_premium(t):
    return ff_table['SMB'].loc[t]
def value_premium(t):
    return ff_table['HML'].loc[t]

# %%
def get_const(t):
    return c_table['const'].loc[t]
def get_mkt(t):
    return c_table['mkt-rf'].loc[t]
def get_SMB(t):
    return c_table['SMB'].loc[t]
def get_HML(t):
    return c_table['HML'].loc[t]

# %%
#calculate expected return from above result
#with 10 day window
def er(t):
    return rf(t-10) + get_mkt(t-10) * market_premium(t-10) + get_SMB(t-10) * size_premium(t-10) + get_HML(t-10) * value_premium(t-10)

# %%
expected_daily_return = []
abnormal = []
for i in range(11,784,1):
    a = er(i)
    expected_daily_return.append(a)
er_table = pd.DataFrame (expected_daily_return, columns = ['ER'])
er_table.index = er_table.index + 1
er_table
# Out:
#            ER
# 1    0.001696
# 2    0.014981
# 3   -0.000916
# 4    0.010611
# 5   -0.003322
# ..        ...
# 769  0.002214
# 770  0.004565
# 771 -0.002358
# 772 -0.007997
# 773  0.003598
#
# [773 rows x 1 columns]

# %%
#modify data size(need to drop the first 130 days)
variable_table = joint.drop(index = joint.index[0:129])
variable_table.index = variable_table.index - 128
variable_table
# Out:
#           公司       Date Industry  Receivable Turnover Ratio  Debt Ratio  \
# 1    1215 卜蜂 2019-07-23     油脂飼料                       8.62       57.43
# 2    1215 卜蜂 2019-07-24     油脂飼料                       8.62       57.43
# 3    1215 卜蜂 2019-07-25     油脂飼料                       8.62       57.43
# 4    1215 卜蜂 2019-07-26     油脂飼料                       8.62       57.43
# 5    1215 卜蜂 2019-07-29     油脂飼料                       8.62       57.43
# ..       ...        ...      ...                        ...         ...
# 769  1215 卜蜂 2022-09-23     油脂飼料                       9.97       63.59
# 770  1215 卜蜂 2022-09-26     油脂飼料                       9.97       63.59
# 771  1215 卜蜂 2022-09-27     油脂飼料                       9.97       63.59
# 772  1215 卜蜂 2022-09-28     油脂飼料                       9.97       63.59
# 773  1215 卜蜂 2022-09-29     油脂飼料                       9.97       63.59
#
#     集團控制型態  Revenue(k/per Month)  ROA(Pre-tax)  ROE(After-tax)  Age  \
# 1        F               1745142          5.95           12.84   32
# 2        F               1745142          5.95           12.84   32
# 3        F               1745142          5.95           12.84   32
# 4        F               1745142          5.95           12.84   32
# 5        F               1745142          5.95           12.84   32
# ..     ...                   ...           ...             ...  ...
# 769      F               2418414          5.28           13.49   35
# 770      F               2418414          5.28           13.49   35
# 771      F               2418414          5.28           13.49   35
# 772      F               2418414          5.28           13.49   35
# 773      F               2418414          5.28           13.49   35
#
#           Open       High        Low      Close  Adj Close  Volume  \
# 1    58.599998  58.599998  57.599998  57.599998  51.007969   53003
# 2    57.599998  58.000000  56.099998  56.200001  49.768188  102118
# 3    56.000000  58.000000  55.500000  57.900002  51.273632   88063
# 4    57.099998  58.799999  57.099998  58.700001  51.982079   63465
# 5    59.500000  59.500000  57.700001  58.700001  51.982079   86359
# ..         ...        ...        ...        ...        ...     ...
# 769  51.500000  52.299999  51.500000  52.299999  52.299999    2010
# 770  52.099998  52.299999  51.500000  52.000000  52.000000   20106
# 771  52.000000  52.200001  51.000000  52.200001  52.200001   25487
# 772  51.000000  51.000000  51.000000  51.000000  51.000000   15004
# 773  51.099998  51.099998  51.000000  51.000000  51.000000   14009
#
#      Daily_Return
# 1       -0.015385
# 2       -0.024306
# 3        0.030249
# 4        0.013817
# 5        0.000000
# ..            ...
# 769      0.015534
# 770     -0.005736
# 771      0.003846
# 772     -0.022989
# 773      0.000000
#
# [773 rows x 17 columns]

# %%
variable_table['Abnormal_Return'] = er_table['ER'] - variable_table['Daily_Return']
variable_table
# Out:
#           公司       Date Industry  Receivable Turnover Ratio  Debt Ratio  \
# 1    1215 卜蜂 2019-07-23     油脂飼料                       8.62       57.43
# 2    1215 卜蜂 2019-07-24     油脂飼料                       8.62       57.43
# 3    1215 卜蜂 2019-07-25     油脂飼料                       8.62       57.43
# 4    1215 卜蜂 2019-07-26     油脂飼料                       8.62       57.43
# 5    1215 卜蜂 2019-07-29     油脂飼料                       8.62       57.43
# ..       ...        ...      ...                        ...         ...
# 769  1215 卜蜂 2022-09-23     油脂飼料                       9.97       63.59
# 770  1215 卜蜂 2022-09-26     油脂飼料                       9.97       63.59
# 771  1215 卜蜂 2022-09-27     油脂飼料                       9.97       63.59
# 772  1215 卜蜂 2022-09-28     油脂飼料                       9.97       63.59
# 773  1215 卜蜂 2022-09-29     油脂飼料                       9.97       63.59
#
#     集團控制型態  Revenue(k/per Month)  ROA(Pre-tax)  ROE(After-tax)  Age  \
# 1        F               1745142          5.95           12.84   32
# 2        F               1745142          5.95           12.84   32
# 3        F               1745142          5.95           12.84   32
# 4        F               1745142          5.95           12.84   32
# 5        F               1745142          5.95           12.84   32
# ..     ...                   ...           ...             ...  ...
# 769      F               2418414          5.28           13.49   35
# 770      F               2418414          5.28           13.49   35
# 771      F               2418414          5.28           13.49   35
# 772      F               2418414          5.28           13.49   35
# 773      F               2418414          5.28           13.49   35
#
#           Open       High        Low      Close  Adj Close  Volume  \
# 1    58.599998  58.599998  57.599998  57.599998  51.007969   53003
# 2    57.599998  58.000000  56.099998  56.200001  49.768188  102118
# 3    56.000000  58.000000  55.500000  57.900002  51.273632   88063
# 4    57.099998  58.799999  57.099998  58.700001  51.982079   63465
# 5    59.500000  59.500000  57.700001  58.700001  51.982079   86359
# ..         ...        ...        ...        ...        ...     ...
# 769  51.500000  52.299999  51.500000  52.299999  52.299999    2010
# 770  52.099998  52.299999  51.500000  52.000000  52.000000   20106
# 771  52.000000  52.200001  51.000000  52.200001  52.200001   25487
# 772  51.000000  51.000000  51.000000  51.000000  51.000000   15004
# 773  51.099998  51.099998  51.000000  51.000000  51.000000   14009
#
#      Daily_Return  Abnormal_Return
# 1       -0.015385         0.017080
# 2       -0.024306         0.039287
# 3        0.030249        -0.031165
# 4        0.013817        -0.003206
# 5        0.000000        -0.003322
# ..            ...              ...
# 769      0.015534        -0.013320
# 770     -0.005736         0.010301
# 771      0.003846        -0.006204
# 772     -0.022989         0.014992
# 773      0.000000         0.003598
#
# [773 rows x 18 columns]

# %%
# ignore it
def get_index(t):
    return variable_table.index[variable_table['Date']==t].tolist()[0]

# %%
# Calculate 3 days cumulative abnormal return
def car(t):
    return (variable_table['Abnormal_Return'].loc[t+1]+variable_table['Abnormal_Return'].loc[t+2]+variable_table['Abnormal_Return'].loc[t+3])
car(0)
# Out:
# 0.025202833741167423

# %%
#collect the result from cumulative abnormal return
car_table = []
for i in range(0,771,1):
    car_table.append(car(i))
car_table = pd.DataFrame(car_table, columns = ['3-day-CAR'])
car_table.index = car_table.index+1
car_table
# Out:
#      3-day-CAR
# 1     0.025203
# 2     0.004916
# 3    -0.037693
# 4     0.003053
# 5     0.019051
# ..         ...
# 767   0.007681
# 768   0.002167
# 769  -0.009223
# 770   0.019088
# 771   0.012385
#
# [771 rows x 1 columns]

# %%
# Merge all independent variables into 1 dataframe we need to run the OLS Regression
final = variable_table.copy()
final.drop(final.tail(2).index,inplace = True)
final['3-day-CAR'] = car_table['3-day-CAR']
final = pd.merge(final,ff_table, on = 'Date', how = 'left')
final
# Out:
#           公司       Date Industry  Receivable Turnover Ratio  Debt Ratio  \
# 0    1215 卜蜂 2019-07-23     油脂飼料                       8.62       57.43
# 1    1215 卜蜂 2019-07-24     油脂飼料                       8.62       57.43
# 2    1215 卜蜂 2019-07-25     油脂飼料                       8.62       57.43
# 3    1215 卜蜂 2019-07-26     油脂飼料                       8.62       57.43
# 4    1215 卜蜂 2019-07-29     油脂飼料                       8.62       57.43
# ..       ...        ...      ...                        ...         ...
# 766  1215 卜蜂 2022-09-21     油脂飼料                       9.97       63.59
# 767  1215 卜蜂 2022-09-22     油脂飼料                       9.97       63.59
# 768  1215 卜蜂 2022-09-23     油脂飼料                       9.97       63.59
# 769  1215 卜蜂 2022-09-26     油脂飼料                       9.97       63.59
# 770  1215 卜蜂 2022-09-27     油脂飼料                       9.97       63.59
#
#     集團控制型態  Revenue(k/per Month)  ROA(Pre-tax)  ROE(After-tax)  Age  ...  \
# 0        F               1745142          5.95           12.84   32  ...
# 1        F               1745142          5.95           12.84   32  ...
# 2        F               1745142          5.95           12.84   32  ...
# 3        F               1745142          5.95           12.84   32  ...
# 4        F               1745142          5.95           12.84   32  ...
# ..     ...                   ...           ...             ...  ...  ...
# 766      F               2418414          5.28           13.49   35  ...
# 767      F               2418414          5.28           13.49   35  ...
# 768      F               2418414          5.28           13.49   35  ...
# 769      F               2418414          5.28           13.49   35  ...
# 770      F               2418414          5.28           13.49   35  ...
#
#      Adj Close  Volume  Daily_Return  Abnormal_Return  3-day-CAR    market  \
# 0    51.007969   53003     -0.015385         0.017080   0.025203  0.000249
# 1    49.768188  102118     -0.024306         0.039287   0.004916 -0.001050
# 2    51.273632   88063      0.030249        -0.031165  -0.037693  0.000517
# 3    51.982079   63465      0.013817        -0.003206   0.003053 -0.004518
# 4    51.982079   86359      0.000000        -0.003322   0.019051 -0.000574
# ..         ...     ...           ...              ...        ...       ...
# 766  51.700001   13356     -0.013359         0.015814   0.007681 -0.008576
# 767  51.500000    3000     -0.003868         0.005186   0.002167 -0.009698
# 768  52.299999    2010      0.015534        -0.013320  -0.009223 -0.011638
# 769  52.000000   20106     -0.005736         0.010301   0.019088 -0.024096
# 770  52.200001   25487      0.003846        -0.006204   0.012385  0.003513
#
#           rf       SMB       HML    mkt-rf
# 0    0.00665 -0.052059 -0.006948 -0.006401
# 1    0.00675 -0.022355  0.071122 -0.007800
# 2    0.00674  0.142433  0.051578 -0.006223
# 3    0.00690  0.144194 -0.196937 -0.011418
# 4    0.00695 -0.035115  0.009478 -0.007524
# ..       ...       ...       ...       ...
# 766  0.01395  0.029670 -0.186107 -0.022526
# 767  0.01395  0.051811 -0.187096 -0.023648
# 768  0.01402  0.067400 -0.452997 -0.025658
# 769  0.01475 -0.234168 -0.305070 -0.038846
# 770  0.01665  0.150132  0.116685 -0.013137
#
# [771 rows x 24 columns]

# %%
#X is the independent variables
#Y is the dependent variables
#Adj R-square is the coefficient of determination between 0-1
#for interpretation: https://www.geeksforgeeks.org/interpreting-the-results-of-linear-regression-using-ols-summary/
# t – statistics are calculated by assuming  following hypothesis – 
# H0  : B2  = 0       ( variable X has no influence on Y)
# Ha  : B2  ≠ 0      (X has significant impact on Y)
X = final[['Receivable Turnover Ratio', 'Debt Ratio', 'Revenue(k/per Month)','ROA(Pre-tax)','ROE(After-tax)','Age','SMB','HML','mkt-rf']]
y = final['3-day-CAR']
X = sm.add_constant(X)
ff_model = sm.OLS(y, X).fit()
print(ff_model.summary())
# intercept, b1, b2, b3, b4, b5, b6, b7, b8, b9 = ff_model.params
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              3-day-CAR   R-squared:                       0.090
# Model:                            OLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     8.390
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):           5.32e-12
# Time:                        22:43:30   Log-Likelihood:                 1458.7
# No. Observations:                 771   AIC:                            -2897.
# Df Residuals:                     761   BIC:                            -2851.
# Df Model:                           9
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.3902      0.141      2.758      0.006       0.112       0.668
# Receivable Turnover Ratio    -0.0002      0.005     -0.032      0.974      -0.010       0.010
# Debt Ratio                    0.0034      0.001      3.717      0.000       0.002       0.005
# Revenue(k/per Month)       6.606e-10   1.13e-08      0.058      0.954   -2.16e-08    2.29e-08
# ROA(Pre-tax)                 -0.0008      0.011     -0.079      0.937      -0.022       0.020
# ROE(After-tax)             -7.66e-05      0.005     -0.016      0.987      -0.010       0.010
# Age                          -0.0174      0.005     -3.177      0.002      -0.028      -0.007
# SMB                          -0.0396      0.014     -2.766      0.006      -0.068      -0.011
# HML                           0.0007      0.013      0.056      0.955      -0.025       0.027
# mkt-rf                       -0.5189      0.277     -1.875      0.061      -1.062       0.024
# ==============================================================================
# Omnibus:                      240.592   Durbin-Watson:                   0.713
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2335.785
# Skew:                          -1.115   Prob(JB):                         0.00
# Kurtosis:                      11.230   Cond. No.                     4.32e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.32e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df0 = final[['Receivable Turnover Ratio', 'Debt Ratio', 'Revenue(k/per Month)','ROA(Pre-tax)','ROE(After-tax)','Age','SMB','HML','mkt-rf','3-day-CAR']]
df0
rdf0 = df0.corr()
sns.set(font_scale = 1.0)
sns.set_context({"figure.figsize":(12,10)})
sns.heatmap(data = rdf0, square = True, cmap = "crest", annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df0, x_vars = ['Receivable Turnover Ratio', 'Debt Ratio', 'Revenue(k/per Month)'], y_vars = '3-day-CAR', size=7, aspect=0.8, kind='reg')  
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df0[['Receivable Turnover Ratio', 'Debt Ratio', 'Revenue(k/per Month)','ROA(Pre-tax)','ROE(After-tax)','Age']], hue = 'Age')
plt.show()
